# %% [markdown]
# # COGS 118B Final Project - FIFA

# %% [markdown]
# ## Team Name: Hong Shao Rou
#
# - Sue Xia
# - Yu Pan
# - Weichong Ling
# - Huiran Song
# - Danrui Wang

# %% [markdown]
# ## Library Import

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Clean

# %%
#Read the data
df = pd.read_csv('players_20.csv')

# %%
#rough data overview
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
#summary statistics
print(df.shape)
df.describe()
# Out:
# (18278, 104)
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# std        6.139669  5.585481e+06   21351.714095                  0.378861
# min       49.000000  0.000000e+00       0.000000                  1.000000
# 25%       67.000000  3.250000e+05    1000.000000                  1.000000
# 50%       71.000000  7.000000e+05    3000.000000                  1.000000
# 75%       75.000000  2.100000e+06    8000.000000                  1.000000
# max       95.000000  1.055000e+08  565000.000000                  5.000000
#
#           weak_foot  ...  mentality_penalties  mentality_composure  \
# count  18278.000000  ...         18278.000000         18278.000000
# mean       2.944250  ...            48.383357            58.528778
# std        0.664656  ...            15.708099            11.880840
# min        1.000000  ...             7.000000            12.000000
# 25%        3.000000  ...            39.000000            51.000000
# 50%        3.000000  ...            49.000000            60.000000
# 75%        3.000000  ...            60.000000            67.000000
# max        5.000000  ...            92.000000            96.000000
#
#        defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# count       18278.000000               18278.000000              18278.000000
# mean           46.848889                  47.640333                 45.606631
# std            20.091287                  21.585641                 21.217734
# min             1.000000                   5.000000                  3.000000
# 25%            29.000000                  27.000000                 24.000000
# 50%            52.000000                  55.000000                 52.000000
# 75%            64.000000                  66.000000                 64.000000
# max            94.000000                  92.000000                 90.000000
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# count        18278.000000          18278.000000         18278.000000
# mean            16.572765             16.354853            16.212934
# std             17.738069             16.996925            16.613665
# min              1.000000              1.000000             1.000000
# 25%              8.000000              8.000000             8.000000
# 50%             11.000000             11.000000            11.000000
# 75%             14.000000             14.000000            14.000000
# max             90.000000             92.000000            93.000000
#
#        goalkeeping_positioning  goalkeeping_reflexes
# count             18278.000000          18278.000000
# mean                 16.368038             16.709924
# std                  17.136497             18.038125
# min                   1.000000              1.000000
# 25%                   8.000000              8.000000
# 50%                  11.000000             11.000000
# 75%                  14.000000             14.000000
# max                  91.000000             92.000000
#
# [8 rows x 61 columns]

# %%
#drop the columns with no value
df_any = df.dropna(axis='columns')
df_any.shape
# Out:
# (18278, 56)

# %%
# Drop columns in which more than 10% of values are missing:
df_10 = df.dropna(thresh=len(df)*0.9, axis='columns')
df_10.shape
# Out:
# (18278, 61)

# %%
# determine which columns have missing data
df_10.isna().any()
# Out:
# sofifa_id                  False
# player_url                 False
# short_name                 False
# long_name                  False
# age                        False
#                            ...
# goalkeeping_diving         False
# goalkeeping_handling       False
# goalkeeping_kicking        False
# goalkeeping_positioning    False
# goalkeeping_reflexes       False
# Length: 61, dtype: bool

# %%
# how many missing values in df_10
df_10.isna().sum().sum()
# Out:
# 3306

# %% [markdown]
# I made 2 dataframes:
# - df_any dropped all columns with missing values
# - df_10 dropped the columns have more than 10% missing values.
#
# I suggest to use df_any, but you could use df_10 if you want.

# %%
# Check columns
df_any.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'player_positions', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'real_face', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes'],
#       dtype='object')

# %%
##############

# %%
df_numeric = df.select_dtypes(include=[np.number])
temp = df['player_positions']
df_numeric['positions'] = temp
df_numeric
# Out:
# <ipython-input-11-ccfead3bc93e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_numeric['positions'] = temp
#        sofifa_id  age  height_cm  weight_kg  overall  potential  value_eur  \
# 0         158023   32        170         72       94         94   95500000
# 1          20801   34        187         83       93         93   58500000
# 2         190871   27        175         68       92         92  105500000
# 3         200389   26        188         87       91         93   77500000
# 4         183277   28        175         74       91         91   90000000
# ...          ...  ...        ...        ...      ...        ...        ...
# 18273     245006   22        186         79       48         56      40000
# 18274     250995   22        177         66       48         56      40000
# 18275     252332   19        186         75       48         56      40000
# 18276     251110   18        185         74       48         54      40000
# 18277     233449   26        182         78       48         51      40000
#
#        wage_eur  international_reputation  weak_foot  ...  \
# 0        565000                         5          4  ...
# 1        405000                         5          4  ...
# 2        290000                         5          5  ...
# 3        125000                         3          3  ...
# 4        470000                         4          4  ...
# ...         ...                       ...        ...  ...
# 18273      2000                         1          3  ...
# 18274      2000                         1          2  ...
# 18275      1000                         1          2  ...
# 18276      1000                         1          2  ...
# 18277      2000                         1          3  ...
#
#        mentality_composure  defending_marking  defending_standing_tackle  \
# 0                       96                 33                         37
# 1                       95                 28                         32
# 2                       94                 27                         26
# 3                       68                 27                         12
# 4                       91                 34                         27
# ...                    ...                ...                        ...
# 18273                   41                 45                         50
# 18274                   35                 42                         53
# 18275                   39                 46                         52
# 18276                   40                 39                         44
# 18277                   42                 52                         42
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            26                   6                    11
# 1                            24                   7                    11
# 2                            29                   9                     9
# 3                            18                  87                    92
# 4                            22                  11                    12
# ...                         ...                 ...                   ...
# 18273                        52                   5                     5
# 18274                        57                  13                     6
# 18275                        46                   7                     8
# 18276                        54                  14                     9
# 18277                        48                   8                    12
#
#        goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# 0                       15                       14                     8
# 1                       15                       14                    11
# 2                       15                       15                    11
# 3                       78                       90                    89
# 4                        6                        8                     8
# ...                    ...                      ...                   ...
# 18273                   13                        5                    14
# 18274                   14                       11                     9
# 18275                   10                        6                    14
# 18276                   13                       13                    13
# 18277                   14                        9                    10
#
#         positions
# 0      RW, CF, ST
# 1          ST, LW
# 2         LW, CAM
# 3              GK
# 4          LW, CF
# ...           ...
# 18273          CB
# 18274          CB
# 18275          CM
# 18276          CM
# 18277          CM
#
# [18278 rows x 62 columns]

# %%
df_numeric = df_numeric.drop(['sofifa_id','value_eur', 'wage_eur', 'international_reputation','release_clause_eur', 'team_jersey_number',
       'contract_valid_until', 'nation_jersey_number','gk_diving','gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
       'gk_positioning'],axis=1)

# %%
df_numeric.isna().sum()
# Out:
# age                              0
# height_cm                        0
# weight_kg                        0
# overall                          0
# potential                        0
# weak_foot                        0
# skill_moves                      0
# pace                          2036
# shooting                      2036
# passing                       2036
# dribbling                     2036
# defending                     2036
# physic                        2036
# attacking_crossing               0
# attacking_finishing              0
# attacking_heading_accuracy       0
# attacking_short_passing          0
# attacking_volleys                0
# skill_dribbling                  0
# skill_curve                      0
# skill_fk_accuracy                0
# skill_long_passing               0
# skill_ball_control               0
# movement_acceleration            0
# movement_sprint_speed            0
# movement_agility                 0
# movement_reactions               0
# movement_balance                 0
# power_shot_power                 0
# power_jumping                    0
# power_stamina                    0
# power_strength                   0
# power_long_shots                 0
# mentality_aggression             0
# mentality_interceptions          0
# mentality_positioning            0
# mentality_vision                 0
# mentality_penalties              0
# mentality_composure              0
# defending_marking                0
# defending_standing_tackle        0
# defending_sliding_tackle         0
# goalkeeping_diving               0
# goalkeeping_handling             0
# goalkeeping_kicking              0
# goalkeeping_positioning          0
# goalkeeping_reflexes             0
# positions                        0
# dtype: int64

# %%
df_numeric = df_numeric.dropna()

# %%
df_pos = df_numeric['positions']
df_numeric = df_numeric.drop(['positions'],axis = 1)

# %%
print(df_numeric.shape)
print(df_pos.shape)
# Out:
# (16242, 47)
# (16242,)

# %%
df_numeric.head(10)
# Out:
#     age  height_cm  weight_kg  overall  potential  weak_foot  skill_moves  \
# 0    32        170         72       94         94          4            4
# 1    34        187         83       93         93          4            5
# 2    27        175         68       92         92          5            5
# 4    28        175         74       91         91          4            4
# 5    28        181         70       91         91          5            4
# 7    27        193         92       90         91          3            2
# 8    33        172         66       90         90          4            4
# 9    27        175         71       90         90          3            4
# 10   20        178         73       89         95          4            5
# 11   28        187         89       89         91          3            2
#
#     pace  shooting  passing  ...  mentality_penalties  mentality_composure  \
# 0   87.0      92.0     92.0  ...                   75                   96
# 1   90.0      93.0     82.0  ...                   85                   95
# 2   91.0      85.0     87.0  ...                   90                   94
# 4   91.0      83.0     86.0  ...                   88                   91
# 5   76.0      86.0     92.0  ...                   79                   91
# 7   77.0      60.0     70.0  ...                   62                   89
# 8   74.0      76.0     89.0  ...                   82                   92
# 9   93.0      86.0     81.0  ...                   77                   91
# 10  96.0      84.0     78.0  ...                   70                   84
# 11  71.0      28.0     54.0  ...                   33                   82
#
#     defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# 0                  33                         37                        26
# 1                  28                         32                        24
# 2                  27                         26                        29
# 4                  34                         27                        22
# 5                  68                         58                        51
# 7                  91                         92                        85
# 8                  68                         76                        71
# 9                  38                         43                        41
# 10                 34                         34                        32
# 11                 91                         90                        87
#
#     goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                    6                    11                   15
# 1                    7                    11                   15
# 2                    9                     9                   15
# 4                   11                    12                    6
# 5                   15                    13                    5
# 7                   13                    10                   13
# 8                   13                     9                    7
# 9                   14                    14                    9
# 10                  13                     5                    7
# 11                   7                    11                    7
#
#     goalkeeping_positioning  goalkeeping_reflexes
# 0                        14                     8
# 1                        14                    11
# 2                        15                    11
# 4                         8                     8
# 5                        10                    13
# 7                        11                    11
# 8                        14                     9
# 9                        11                    14
# 10                       11                     6
# 11                       13                     5
#
# [10 rows x 47 columns]

# %% [markdown]
# ## Data Exploration and Analysis

# %% [markdown]
# Explore what cleaning does to the raw data:

# %%
# cols in df_any but not in df_numeric
for i in range(df_any.shape[1]):
    if df_any.columns[i] not in df_numeric.columns:
        print(df_any.columns[i])
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# dob
# nationality
# club
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# work_rate
# body_type
# real_face

# %%
# cols in df but not in df_any
for i in range(df.shape[1]):
    if df.columns[i] not in df_any.columns:
        print(df.columns[i])
# Out:
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# ls
# st
# rs
# lw
# lf
# cf
# rf
# rw
# lam
# cam
# ram
# lm
# lcm
# cm
# rcm
# rm
# lwb
# ldm
# cdm
# rdm
# rwb
# lb
# lcb
# cb
# rcb
# rb

# %%
print(df_numeric.columns)
# Out:
# Index(['age', 'height_cm', 'weight_kg', 'overall', 'potential', 'weak_foot',
#        'skill_moves', 'pace', 'shooting', 'passing', 'dribbling', 'defending',
#        'physic', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes'],
#       dtype='object')

# %% [markdown]
# Examine the dropped columns not in df_any:

# %%
df_any_dropped = df.drop(df_any.columns,axis=1)
df_any_dropped.columns
# Out:
# Index(['release_clause_eur', 'player_tags', 'team_position',
#        'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until',
#        'nation_position', 'nation_jersey_number', 'pace', 'shooting',
#        'passing', 'dribbling', 'defending', 'physic', 'gk_diving',
#        'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'player_traits', 'ls', 'st', 'rs', 'lw', 'lf', 'cf',
#        'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb',
#        'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object')

# %%
for i in df_any_dropped.columns:
    print(i+":")
    print(df_any_dropped[i].isna().sum()/len(df_any_dropped))
# Out:
# release_clause_eur:
# 0.07101433417222891
# player_tags:
# 0.9179888390414707
# team_position:
# 0.01313053944632892
# team_jersey_number:
# 0.01313053944632892
# loaned_from:
# 0.9426633110843637
# joined:
# 0.0704672283619652
# contract_valid_until:
# 0.01313053944632892
# nation_position:
# 0.9383958857643068
# nation_jersey_number:
# 0.9383958857643068
# pace:
# 0.11139074296969034
# shooting:
# 0.11139074296969034
# passing:
# 0.11139074296969034
# dribbling:
# 0.11139074296969034
# defending:
# 0.11139074296969034
# physic:
# 0.11139074296969034
# gk_diving:
# 0.8886092570303097
# gk_handling:
# 0.8886092570303097
# gk_kicking:
# 0.8886092570303097
# gk_reflexes:
# 0.8886092570303097
# gk_speed:
# 0.8886092570303097
# gk_positioning:
# 0.8886092570303097
# player_traits:
# 0.5860597439544808
# ls:
# 0.11139074296969034
# st:
# 0.11139074296969034
# rs:
# 0.11139074296969034
# lw:
# 0.11139074296969034
# lf:
# 0.11139074296969034
# cf:
# 0.11139074296969034
# rf:
# 0.11139074296969034
# rw:
# 0.11139074296969034
# lam:
# 0.11139074296969034
# cam:
# 0.11139074296969034
# ram:
# 0.11139074296969034
# lm:
# 0.11139074296969034
# lcm:
# 0.11139074296969034
# cm:
# 0.11139074296969034
# rcm:
# 0.11139074296969034
# rm:
# 0.11139074296969034
# lwb:
# 0.11139074296969034
# ldm:
# 0.11139074296969034
# cdm:
# 0.11139074296969034
# rdm:
# 0.11139074296969034
# rwb:
# 0.11139074296969034
# lb:
# 0.11139074296969034
# lcb:
# 0.11139074296969034
# cb:
# 0.11139074296969034
# rcb:
# 0.11139074296969034
# rb:
# 0.11139074296969034

# %% [markdown]
# A lot of semantically significant columns have <12% NAs. Since the original dataframe have over 18,000 datapoints, we are adding the columns with low percentage of NAs back and dropping the rows missing those features.

# %%
for i in df_any_dropped.columns:
    if (df_any_dropped[i].isna().sum()/len(df_any_dropped)) > 0.12:
        df_any_dropped.drop(i,axis=1,inplace=True)
        
df_cleaned = pd.concat([df_any,df_any_dropped],axis=1).dropna()
df_cleaned.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential',
#        'value_eur', 'wage_eur', 'player_positions', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'real_face', 'attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'release_clause_eur',
#        'team_position', 'team_jersey_number', 'joined', 'contract_valid_until',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'ls',
#        'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm',
#        'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb',
#        'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object')

# %% [markdown]
# Now there are multiple semantically similar columns in the dataframe such as sofifa_id, short_name and long_name.

# %%
pd.set_option('display.max_columns', None)  
df_cleaned.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
# 5     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
# 5       K. De Bruyne                      Kevin De Bruyne   28  1991-06-28
#
#    height_cm  weight_kg nationality                 club  overall  potential  \
# 0        170         72   Argentina         FC Barcelona       94         94
# 1        187         83    Portugal             Juventus       93         93
# 2        175         68      Brazil  Paris Saint-Germain       92         92
# 4        175         74     Belgium          Real Madrid       91         91
# 5        181         70     Belgium      Manchester City       91         91
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0   95500000    565000       RW, CF, ST           Left
# 1   58500000    405000           ST, LW          Right
# 2  105500000    290000          LW, CAM          Right
# 4   90000000    470000           LW, CF          Right
# 5   90000000    370000          CAM, CM          Right
#
#    international_reputation  weak_foot  skill_moves    work_rate   body_type  \
# 0                         5          4            4   Medium/Low       Messi
# 1                         5          4            5     High/Low  C. Ronaldo
# 2                         5          5            5  High/Medium      Neymar
# 4                         4          4            4  High/Medium      Normal
# 5                         4          5            4    High/High      Normal
#
#   real_face  attacking_crossing  attacking_finishing  \
# 0       Yes                  88                   95
# 1       Yes                  84                   94
# 2       Yes                  87                   87
# 4       Yes                  81                   84
# 5       Yes                  93                   82
#
#    attacking_heading_accuracy  attacking_short_passing  attacking_volleys  \
# 0                          70                       92                 88
# 1                          89                       83                 87
# 2                          62                       87                 87
# 4                          61                       89                 83
# 5                          55                       92                 82
#
#    skill_dribbling  skill_curve  skill_fk_accuracy  skill_long_passing  \
# 0               97           93                 94                  92
# 1               89           81                 76                  77
# 2               96           88                 87                  81
# 4               95           83                 79                  83
# 5               86           85                 83                  91
#
#    skill_ball_control  movement_acceleration  movement_sprint_speed  \
# 0                  96                     91                     84
# 1                  92                     89                     91
# 2                  95                     94                     89
# 4                  94                     94                     88
# 5                  91                     77                     76
#
#    movement_agility  movement_reactions  movement_balance  power_shot_power  \
# 0                93                  95                95                86
# 1                87                  96                71                95
# 2                96                  92                84                80
# 4                95                  90                94                82
# 5                78                  91                76                91
#
#    power_jumping  power_stamina  power_strength  power_long_shots  \
# 0             68             75              68                94
# 1             95             85              78                93
# 2             61             81              49                84
# 4             56             84              63                80
# 5             63             89              74                90
#
#    mentality_aggression  mentality_interceptions  mentality_positioning  \
# 0                    48                       40                     94
# 1                    63                       29                     95
# 2                    51                       36                     87
# 4                    54                       41                     87
# 5                    76                       61                     88
#
#    mentality_vision  mentality_penalties  mentality_composure  \
# 0                94                   75                   96
# 1                82                   85                   95
# 2                90                   90                   94
# 4                89                   88                   91
# 5                94                   79                   91
#
#    defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# 0                 33                         37                        26
# 1                 28                         32                        24
# 2                 27                         26                        29
# 4                 34                         27                        22
# 5                 68                         58                        51
#
#    goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                   6                    11                   15
# 1                   7                    11                   15
# 2                   9                     9                   15
# 4                  11                    12                    6
# 5                  15                    13                    5
#
#    goalkeeping_positioning  goalkeeping_reflexes  release_clause_eur  \
# 0                       14                     8         195800000.0
# 1                       14                    11          96500000.0
# 2                       15                    11         195200000.0
# 4                        8                     8         184500000.0
# 5                       10                    13         166500000.0
#
#   team_position  team_jersey_number      joined  contract_valid_until  pace  \
# 0            RW                10.0  2004-07-01                2021.0  87.0
# 1            LW                 7.0  2018-07-10                2022.0  90.0
# 2           CAM                10.0  2017-08-03                2022.0  91.0
# 4            LW                 7.0  2019-07-01                2024.0  91.0
# 5           RCM                17.0  2015-08-30                2023.0  76.0
#
#    shooting  passing  dribbling  defending  physic    ls    st    rs    lw  \
# 0      92.0     92.0       96.0       39.0    66.0  89+2  89+2  89+2  93+2
# 1      93.0     82.0       89.0       35.0    78.0  91+3  91+3  91+3  89+3
# 2      85.0     87.0       95.0       32.0    58.0  84+3  84+3  84+3  90+3
# 4      83.0     86.0       94.0       35.0    66.0  83+3  83+3  83+3  89+3
# 5      86.0     92.0       86.0       61.0    78.0  82+3  82+3  82+3  87+3
#
#      lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm   rcm    rm  \
# 0  93+2  93+2  93+2  93+2  93+2  93+2  93+2  92+2  87+2  87+2  87+2  92+2
# 1  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3  81+3  81+3  81+3  88+3
# 2  89+3  89+3  89+3  90+3  90+3  90+3  90+3  89+3  82+3  82+3  82+3  89+3
# 4  88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3  83+3  83+3  83+3  89+3
# 5  87+3  87+3  87+3  87+3  88+3  88+3  88+3  88+3  87+3  87+3  87+3  88+3
#
#     lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  68+2  66+2  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  66+3  61+3  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 4  66+3  63+3  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
# 5  77+3  77+3  77+3  77+3  77+3  73+3  66+3  66+3  66+3  73+3

# %%
df_cleaned.drop(['player_url', 'short_name', 'long_name'],axis=1, inplace=True)
df_cleaned.shape
# Out:
# (15077, 90)

# %% [markdown]
# There are still 90 columns in df_any. Compare it with df_numeric:

# %%
df_num_dropped = df_cleaned.drop(df_numeric.columns,axis=1)
df_num_dropped.dtypes
# Out:
# sofifa_id                     int64
# dob                          object
# nationality                  object
# club                         object
# value_eur                     int64
# wage_eur                      int64
# player_positions             object
# preferred_foot               object
# international_reputation      int64
# work_rate                    object
# body_type                    object
# real_face                    object
# release_clause_eur          float64
# team_position                object
# team_jersey_number          float64
# joined                       object
# contract_valid_until        float64
# ls                           object
# st                           object
# rs                           object
# lw                           object
# lf                           object
# cf                           object
# rf                           object
# rw                           object
# lam                          object
# cam                          object
# ram                          object
# lm                           object
# lcm                          object
# cm                           object
# rcm                          object
# rm                           object
# lwb                          object
# ldm                          object
# cdm                          object
# rdm                          object
# rwb                          object
# lb                           object
# lcb                          object
# cb                           object
# rcb                          object
# rb                           object
# dtype: object

# %% [markdown]
# Examine the object columns first:

# %%
df_num_dropped.select_dtypes('object')
# Out:
#               dob          nationality                           club  \
# 0      1987-06-24            Argentina                   FC Barcelona
# 1      1985-02-05             Portugal                       Juventus
# 2      1992-02-05               Brazil            Paris Saint-Germain
# 4      1991-01-07              Belgium                    Real Madrid
# 5      1991-06-28              Belgium                Manchester City
# ...           ...                  ...                            ...
# 18271  1999-03-01  Republic of Ireland                     Derry City
# 18273  1997-03-10             China PR               Beijing Renhe FC
# 18274  1997-01-01             China PR               Shanghai SIPG FC
# 18275  2000-05-16             China PR         Hebei China Fortune FC
# 18276  2000-08-02             China PR  Shanghai Greenland Shenhua FC
#
#       player_positions preferred_foot      work_rate   body_type real_face  \
# 0           RW, CF, ST           Left     Medium/Low       Messi       Yes
# 1               ST, LW          Right       High/Low  C. Ronaldo       Yes
# 2              LW, CAM          Right    High/Medium      Neymar       Yes
# 4               LW, CF          Right    High/Medium      Normal       Yes
# 5              CAM, CM          Right      High/High      Normal       Yes
# ...                ...            ...            ...         ...       ...
# 18271               CM          Right  Medium/Medium      Normal        No
# 18273               CB          Right    Medium/High      Normal        No
# 18274               CB          Right  Medium/Medium      Normal        No
# 18275               CM          Right     Low/Medium        Lean        No
# 18276               CM          Right        Low/Low        Lean        No
#
#       team_position      joined    ls    st    rs    lw    lf    cf    rf  \
# 0                RW  2004-07-01  89+2  89+2  89+2  93+2  93+2  93+2  93+2
# 1                LW  2018-07-10  91+3  91+3  91+3  89+3  90+3  90+3  90+3
# 2               CAM  2017-08-03  84+3  84+3  84+3  90+3  89+3  89+3  89+3
# 4                LW  2019-07-01  83+3  83+3  83+3  89+3  88+3  88+3  88+3
# 5               RCM  2015-08-30  82+3  82+3  82+3  87+3  87+3  87+3  87+3
# ...             ...         ...   ...   ...   ...   ...   ...   ...   ...
# 18271           SUB  2018-02-23  43+2  43+2  43+2  44+2  44+2  44+2  44+2
# 18273           RES  2018-07-13  32+2  32+2  32+2  31+2  31+2  31+2  31+2
# 18274           SUB  2019-02-01  33+2  33+2  33+2  33+2  32+2  32+2  32+2
# 18275           SUB  2019-01-01  43+2  43+2  43+2  43+2  43+2  43+2  43+2
# 18276           SUB  2019-02-01  43+2  43+2  43+2  45+2  44+2  44+2  44+2
#
#          rw   lam   cam   ram    lm   lcm    cm   rcm    rm   lwb   ldm   cdm  \
# 0      93+2  93+2  93+2  93+2  92+2  87+2  87+2  87+2  92+2  68+2  66+2  66+2
# 1      89+3  88+3  88+3  88+3  88+3  81+3  81+3  81+3  88+3  65+3  61+3  61+3
# 2      90+3  90+3  90+3  90+3  89+3  82+3  82+3  82+3  89+3  66+3  61+3  61+3
# 4      89+3  89+3  89+3  89+3  89+3  83+3  83+3  83+3  89+3  66+3  63+3  63+3
# 5      87+3  88+3  88+3  88+3  88+3  87+3  87+3  87+3  88+3  77+3  77+3  77+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 18271  44+2  46+2  46+2  46+2  45+2  46+2  46+2  46+2  45+2  46+2  46+2  46+2
# 18273  31+2  31+2  31+2  31+2  33+2  33+2  33+2  33+2  33+2  43+2  42+2  42+2
# 18274  33+2  33+2  33+2  33+2  35+2  36+2  36+2  36+2  35+2  44+2  43+2  43+2
# 18275  43+2  44+2  44+2  44+2  45+2  46+2  46+2  46+2  45+2  47+2  49+2  49+2
# 18276  45+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2  46+2  48+2  48+2  48+2
#
#         rdm   rwb    lb   lcb    cb   rcb    rb
# 0      66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1      61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2      61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 4      63+3  66+3  61+3  49+3  49+3  49+3  61+3
# 5      77+3  77+3  73+3  66+3  66+3  66+3  73+3
# ...     ...   ...   ...   ...   ...   ...   ...
# 18271  46+2  46+2  46+2  45+2  45+2  45+2  46+2
# 18273  42+2  43+2  45+2  46+2  46+2  46+2  45+2
# 18274  43+2  44+2  46+2  47+2  47+2  47+2  46+2
# 18275  49+2  47+2  47+2  49+2  49+2  49+2  47+2
# 18276  48+2  48+2  48+2  49+2  49+2  49+2  48+2
#
# [15077 rows x 36 columns]

# %% [markdown]
# Since date of birth overlaps with age, and it's unlikely to get any result from the day the player was born in, I'm converting "dob" to "mob" (month of birth).
# This might be overkilling, but who knows, maybe virgos make the best players.

# %%
df_cleaned['dob']=df['dob'].str[4:8]
df_cleaned['dob']=df_cleaned['dob'].replace('-', '',regex=True).astype('int64')
df_cleaned = df_cleaned.rename(columns={'dob':'mob'})
# Out:
#        sofifa_id  age  mob  height_cm  weight_kg          nationality  \
# 0         158023   32    6        170         72            Argentina
# 1          20801   34    2        187         83             Portugal
# 2         190871   27    2        175         68               Brazil
# 4         183277   28    1        175         74              Belgium
# 5         192985   28    6        181         70              Belgium
# ...          ...  ...  ...        ...        ...                  ...
# 18271     243961   20    3        180         72  Republic of Ireland
# 18273     245006   22    3        186         79             China PR
# 18274     250995   22    1        177         66             China PR
# 18275     252332   19    5        186         75             China PR
# 18276     251110   18    8        185         74             China PR
#
#                                 club  overall  potential  value_eur  wage_eur  \
# 0                       FC Barcelona       94         94   95500000    565000
# 1                           Juventus       93         93   58500000    405000
# 2                Paris Saint-Germain       92         92  105500000    290000
# 4                        Real Madrid       91         91   90000000    470000
# 5                    Manchester City       91         91   90000000    370000
# ...                              ...      ...        ...        ...       ...
# 18271                     Derry City       48         59      50000      1000
# 18273               Beijing Renhe FC       48         56      40000      2000
# 18274               Shanghai SIPG FC       48         56      40000      2000
# 18275         Hebei China Fortune FC       48         56      40000      1000
# 18276  Shanghai Greenland Shenhua FC       48         54      40000      1000
#
#       player_positions preferred_foot  international_reputation  weak_foot  \
# 0           RW, CF, ST           Left                         5          4
# 1               ST, LW          Right                         5          4
# 2              LW, CAM          Right                         5          5
# 4               LW, CF          Right                         4          4
# 5              CAM, CM          Right                         4          5
# ...                ...            ...                       ...        ...
# 18271               CM          Right                         1          3
# 18273               CB          Right                         1          3
# 18274               CB          Right                         1          2
# 18275               CM          Right                         1          2
# 18276               CM          Right                         1          2
#
#        skill_moves      work_rate   body_type real_face  attacking_crossing  \
# 0                4     Medium/Low       Messi       Yes                  88
# 1                5       High/Low  C. Ronaldo       Yes                  84
# 2                5    High/Medium      Neymar       Yes                  87
# 4                4    High/Medium      Normal       Yes                  81
# 5                4      High/High      Normal       Yes                  93
# ...            ...            ...         ...       ...                 ...
# 18271            2  Medium/Medium      Normal        No                  37
# 18273            2    Medium/High      Normal        No                  21
# 18274            2  Medium/Medium      Normal        No                  24
# 18275            2     Low/Medium        Lean        No                  32
# 18276            2        Low/Low        Lean        No                  39
#
#        attacking_finishing  attacking_heading_accuracy  \
# 0                       95                          70
# 1                       94                          89
# 2                       87                          62
# 4                       84                          61
# 5                       82                          55
# ...                    ...                         ...
# 18271                   35                          49
# 18273                   17                          40
# 18274                   20                          42
# 18275                   33                          49
# 18276                   34                          47
#
#        attacking_short_passing  attacking_volleys  skill_dribbling  \
# 0                           92                 88               97
# 1                           83                 87               89
# 2                           87                 87               96
# 4                           89                 83               95
# 5                           92                 82               86
# ...                        ...                ...              ...
# 18271                       55                 27               41
# 18273                       35                 27               24
# 18274                       43                 28               32
# 18275                       53                 32               40
# 18276                       54                 28               42
#
#        skill_curve  skill_fk_accuracy  skill_long_passing  skill_ball_control  \
# 0               93                 94                  92                  96
# 1               81                 76                  77                  92
# 2               88                 87                  81                  95
# 4               83                 79                  83                  94
# 5               85                 83                  91                  91
# ...            ...                ...                 ...                 ...
# 18271           31                 30                  47                  44
# 18273           23                 21                  28                  35
# 18274           24                 29                  39                  31
# 18275           32                 32                  55                  49
# 18276           37                 39                  48                  49
#
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 0                         91                     84                93
# 1                         89                     91                87
# 2                         94                     89                96
# 4                         94                     88                95
# 5                         77                     76                78
# ...                      ...                    ...               ...
# 18271                     54                     50                63
# 18273                     56                     58                45
# 18274                     55                     61                43
# 18275                     55                     54                52
# 18276                     55                     63                55
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# 0                      95                95                86             68
# 1                      96                71                95             95
# 2                      92                84                80             61
# 4                      90                94                82             56
# 5                      91                76                91             63
# ...                   ...               ...               ...            ...
# 18271                  53                64                47             60
# 18273                  40                73                36             70
# 18274                  41                76                33             72
# 18275                  52                57                48             60
# 18276                  54                59                46             61
#
#        power_stamina  power_strength  power_long_shots  mentality_aggression  \
# 0                 75              68                94                    48
# 1                 85              78                93                    63
# 2                 81              49                84                    51
# 4                 84              63                80                    54
# 5                 89              74                90                    76
# ...              ...             ...               ...                   ...
# 18271             51              45                31                    52
# 18273             60              47                16                    46
# 18274             55              44                20                    42
# 18275             50              51                26                    50
# 18276             42              55                28                    57
#
#        mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                           40                     94                94
# 1                           29                     95                82
# 2                           36                     87                90
# 4                           41                     87                89
# 5                           61                     88                94
# ...                        ...                    ...               ...
# 18271                       45                     37                49
# 18273                       48                     28                25
# 18274                       49                     23                25
# 18275                       45                     38                38
# 18276                       49                     31                48
#
#        mentality_penalties  mentality_composure  defending_marking  \
# 0                       75                   96                 33
# 1                       85                   95                 28
# 2                       90                   94                 27
# 4                       88                   91                 34
# 5                       79                   91                 68
# ...                    ...                  ...                ...
# 18271                   40                   43                 39
# 18273                   39                   41                 45
# 18274                   37                   35                 42
# 18275                   36                   39                 46
# 18276                   36                   40                 39
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             37                        26
# 1                             32                        24
# 2                             26                        29
# 4                             27                        22
# 5                             58                        51
# ...                          ...                       ...
# 18271                         39                        48
# 18273                         50                        52
# 18274                         53                        57
# 18275                         52                        46
# 18276                         44                        54
#
#        goalkeeping_diving  goalkeeping_handling  goalkeeping_kicking  \
# 0                       6                    11                   15
# 1                       7                    11                   15
# 2                       9                     9                   15
# 4                      11                    12                    6
# 5                      15                    13                    5
# ...                   ...                   ...                  ...
# 18271                   6                    11                    9
# 18273                   5                     5                   13
# 18274                  13                     6                   14
# 18275                   7                     8                   10
# 18276                  14                     9                   13
#
#        goalkeeping_positioning  goalkeeping_reflexes  release_clause_eur  \
# 0                           14                     8         195800000.0
# 1                           14                    11          96500000.0
# 2                           15                    11         195200000.0
# 4                            8                     8         184500000.0
# 5                           10                    13         166500000.0
# ...                        ...                   ...                 ...
# 18271                        5                     8             88000.0
# 18273                        5                    14             70000.0
# 18274                       11                     9             72000.0
# 18275                        6                    14             70000.0
# 18276                       13                    13             70000.0
#
#       team_position  team_jersey_number      joined  contract_valid_until  \
# 0                RW                10.0  2004-07-01                2021.0
# 1                LW                 7.0  2018-07-10                2022.0
# 2               CAM                10.0  2017-08-03                2022.0
# 4                LW                 7.0  2019-07-01                2024.0
# 5               RCM                17.0  2015-08-30                2023.0
# ...             ...                 ...         ...                   ...
# 18271           SUB                19.0  2018-02-23                2019.0
# 18273           RES                36.0  2018-07-13                2019.0
# 18274           SUB                31.0  2019-02-01                2022.0
# 18275           SUB                38.0  2019-01-01                2019.0
# 18276           SUB                33.0  2019-02-01                2022.0
#
#        pace  shooting  passing  dribbling  defending  physic    ls    st  \
# 0      87.0      92.0     92.0       96.0       39.0    66.0  89+2  89+2
# 1      90.0      93.0     82.0       89.0       35.0    78.0  91+3  91+3
# 2      91.0      85.0     87.0       95.0       32.0    58.0  84+3  84+3
# 4      91.0      83.0     86.0       94.0       35.0    66.0  83+3  83+3
# 5      76.0      86.0     92.0       86.0       61.0    78.0  82+3  82+3
# ...     ...       ...      ...        ...        ...     ...   ...   ...
# 18271  52.0      37.0     47.0       46.0       42.0    49.0  43+2  43+2
# 18273  57.0      23.0     28.0       33.0       47.0    51.0  32+2  32+2
# 18274  58.0      24.0     33.0       35.0       48.0    48.0  33+2  33+2
# 18275  54.0      35.0     44.0       45.0       48.0    51.0  43+2  43+2
# 18276  59.0      35.0     47.0       47.0       45.0    52.0  43+2  43+2
#
#          rs    lw    lf    cf    rf    rw   lam   cam   ram    lm   lcm    cm  \
# 0      89+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  92+2  87+2  87+2
# 1      91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3  88+3  88+3  81+3  81+3
# 2      84+3  90+3  89+3  89+3  89+3  90+3  90+3  90+3  90+3  89+3  82+3  82+3
# 4      83+3  89+3  88+3  88+3  88+3  89+3  89+3  89+3  89+3  89+3  83+3  83+3
# 5      82+3  87+3  87+3  87+3  87+3  87+3  88+3  88+3  88+3  88+3  87+3  87+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 18271  43+2  44+2  44+2  44+2  44+2  44+2  46+2  46+2  46+2  45+2  46+2  46+2
# 18273  32+2  31+2  31+2  31+2  31+2  31+2  31+2  31+2  31+2  33+2  33+2  33+2
# 18274  33+2  33+2  32+2  32+2  32+2  33+2  33+2  33+2  33+2  35+2  36+2  36+2
# 18275  43+2  43+2  43+2  43+2  43+2  43+2  44+2  44+2  44+2  45+2  46+2  46+2
# 18276  43+2  45+2  44+2  44+2  44+2  45+2  46+2  46+2  46+2  46+2  46+2  46+2
#
#         rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0      87+2  92+2  68+2  66+2  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1      81+3  88+3  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2      82+3  89+3  66+3  61+3  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 4      83+3  89+3  66+3  63+3  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
# 5      87+3  88+3  77+3  77+3  77+3  77+3  77+3  73+3  66+3  66+3  66+3  73+3
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 18271  46+2  45+2  46+2  46+2  46+2  46+2  46+2  46+2  45+2  45+2  45+2  46+2
# 18273  33+2  33+2  43+2  42+2  42+2  42+2  43+2  45+2  46+2  46+2  46+2  45+2
# 18274  36+2  35+2  44+2  43+2  43+2  43+2  44+2  46+2  47+2  47+2  47+2  46+2
# 18275  46+2  45+2  47+2  49+2  49+2  49+2  47+2  47+2  49+2  49+2  49+2  47+2
# 18276  46+2  46+2  48+2  48+2  48+2  48+2  48+2  48+2  49+2  49+2  49+2  48+2
#
# [15077 rows x 90 columns]

# %%
df_cleaned.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-395319aeed73> in <module>
# ----> 1 df_cleaned.value_counts()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
for i in df_any.columns:
    df_any[i].value_counts()[:3].plot(kind='barh')
    plt.show()

# %%
for i in df_any.columns:
    print(i)

# %% [markdown]
# ## K-means

# %% [markdown]
# ## Spectral Clustering

# %% [markdown]
# ## Mixture of Gaussian (MOG)

# %%
df_numeric.head()

# %%
from sklearn.preprocessing import StandardScaler

val = df_numeric.values
scaler = StandardScaler()
scaler.fit(val)
data = scaler.transform(val)
data.shape

# %%
# Initialization k = 11
from scipy.stats import multivariate_normal

np.random.seed(42)
u = np.random.rand(11,47)
sigma = np.identity(47)
pi = np.random.rand(11)

# %%
# E-Step
# Return matrix gamma N*K (18278, 11)
def GMM_E(u,sigma,pi):

# %%
for i in range(11):
    print(multivariate_normal.pdf(data[0], mean=u[i], cov=sigma))
